# %%
from generator import Generator

# %%
generator = Generator()
x_f, y_f, f_expr, f, f_id, input_dimension, org_tree = generator.sample_formula()
# Out:
# Tokenizer initialized. Vocab Size: 53

# %%
f_expr
# Out:
# ['add',
#  '<C>',
#  'min',
#  'abs',
#  'add',
#  '<C>',
#  'mul',
#  '<C>',
#  'mul',
#  'log10',
#  'add',
#  '<C>',
#  'mul',
#  '<C>',
#  'x_0',
#  'sinh',
#  'add',
#  '<C>',
#  'mul',
#  '<C>',
#  'x_1',
#  'mul',
#  'abs',
#  'add',
#  '<C>',
#  'mul',
#  '<C>',
#  'x_3',
#  'x_2']

# %%
generator = Generator()
x_f, y_f, f_expr, f, f_id, input_dimension, org_tree = generator.sample_formula()
# Out:
# Tokenizer initialized. Vocab Size: 53

# %%
f_expr
# Out:
# ['add',
#  '<C>',
#  'min',
#  'abs',
#  'add',
#  '<C>',
#  'mul',
#  '<C>',
#  'mul',
#  'log10',
#  'add',
#  '<C>',
#  'mul',
#  '<C>',
#  'x_0',
#  'sinh',
#  'add',
#  '<C>',
#  'mul',
#  '<C>',
#  'x_1',
#  'mul',
#  'abs',
#  'add',
#  '<C>',
#  'mul',
#  '<C>',
#  'x_3',
#  'x_2']
