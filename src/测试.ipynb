# %%
from generator import Generator

# %%
from pretrain import CacheDataset

# %%
d = CacheDataset('../training_data/dataset_generated_10/dataset.pt')
# Out:
# Loading data from ../training_data/dataset_generated_10/dataset.pt...

# %%
import torch

# %%
d = torch.load('../training_data/metadata.pt')

# %%
d
# Out:
# {'x': tensor([[[-1.0438e+00, -4.6434e-01, -6.9833e-01,  ..., -1.7437e-02,
#             0.0000e+00,  0.0000e+00],
#           [ 6.0772e-01,  1.1166e+00, -8.4890e-01,  ...,  1.4249e+00,
#             0.0000e+00,  0.0000e+00],
#           [-1.4177e+00, -7.1478e-01,  5.7724e-01,  ...,  8.6778e-01,
#             0.0000e+00,  0.0000e+00],
#           ...,
#           [-9.6494e-02,  1.9085e-01, -1.2063e-01,  ...,  4.5941e-02,
#             0.0000e+00,  0.0000e+00],
#           [-1.9976e+00, -1.2615e+00, -1.0302e+00,  ..., -2.8223e-01,
#             0.0000e+00,  0.0000e+00],
#           [-3.2310e-02,  5.4054e-01, -5.8889e-01,  ...,  8.2092e-01,
#             0.0000e+00,  0.0000e+00]],
#
#          [[ 5.5965e-01, -1.1180e+00, -1.4039e+00,  ...,  0.0000e+00,
#             0.0000e+00,  0.0000e+00],
#           [ 3.4846e-01,  3.9445e-01,  6.1784e-01,  ...,  0.0000e+00,
#             0.0000e+00,  0.0000e+00],
#           [-5.3471e-01,  7.6842e-01, -1.2141e+00,  ...,  0.0000e+00,
# ...

# %%
d = torch.load('../training_data/sympfn_top10_data.pt')

# %%
for key in d.keys():
    print(f'{key} shape: {d[key].shape}')
# Out:
# query_x shape: torch.Size([2000, 100, 16])
# query_y shape: torch.Size([2000, 100])
# query_f shape: torch.Size([2000, 103])
# ctx_x shape: torch.Size([2000, 10, 100, 16])
# ctx_y shape: torch.Size([2000, 10, 100])
# ctx_f shape: torch.Size([2000, 10, 103])
